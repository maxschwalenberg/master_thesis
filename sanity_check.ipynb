# %%
import pandas as pd

data = pd.read_excel("data/labels/nsd_coco.xlsx")
# Out:
#        Unnamed: 0  cocoId  cocoSplit  nsdId                   file_name  \
# 30935       30935  354095  train2017  30935  train2017/000000354095.jpg
#
#        amount_participants  subject
# 30935                    8      NaN

# %%
data[
                data["cocoId"] == 354095
            ]
# Out:
#        Unnamed: 0  cocoId  cocoSplit  nsdId                   file_name  \
# 30935       30935  354095  train2017  30935  train2017/000000354095.jpg
#
#        amount_participants  subject
# 30935                    8      NaN
