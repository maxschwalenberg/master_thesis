# %%
from utils.config import load_config, Configuration
config = load_config("config.yaml")

# %%
import numpy as np

path = "data/image_betas/negative/000000000584/subj_02/full.betas_1124.npy"

data = np.load(path)


# Masked betas shape: (85, 4776)
print(data.shape)
